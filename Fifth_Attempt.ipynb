# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import numpy as np

# Load data
train = pd.read_csv('/content/drive/MyDrive/kaggle_heart_disease/train.csv')
test = pd.read_csv('/content/drive/MyDrive/kaggle_heart_disease/test.csv')

# Convert target to 0/1
train['Heart Disease'] = train['Heart Disease'].map({'Absence': 0, 'Presence': 1})

# Original features (no id)
X_orig = train.drop(['id', 'Heart Disease'], axis=1)
y = train['Heart Disease']
X_test_orig = test.drop(['id'], axis=1)
test_ids = test['id']

# Clean column names (replace spaces with underscores)
X_orig.columns = X_orig.columns.str.replace(' ', '_').str.replace('-', '_')
X_test_orig.columns = X_test_orig.columns.str.replace(' ', '_').str.replace('-', '_')

# --- Add manual features (interactions & ratios) ---
def add_manual_features(df):
    df = df.copy()
    df['thal_x_chest'] = df['Thallium'] * df['Chest_pain_type']
    df['exang_x_vessels'] = df['Exercise_angina'] * df['Number_of_vessels_fluro']
    df['stdep_x_slope'] = df['ST_depression'] * df['Slope_of_ST']
    df['age_x_maxhr'] = df['Age'] * df['Max_HR']
    df['bp_per_age'] = df['BP'] / (df['Age'] + 1)
    df['chol_per_age'] = df['Cholesterol'] / (df['Age'] + 1)
    return df

X = add_manual_features(X_orig)
X_test = add_manual_features(X_test_orig)

print(f"Train shape: {X.shape}, Test shape: {X_test.shape}")  # Should match (630000, 19) and (270000, 19)
# Out:
# Mounted at /content/drive
# Train shape: (630000, 19), Test shape: (270000, 19)

# %%
! pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.7.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.18.4)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (26.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.47)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.3.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Downloading optuna-4.7.0-py3-none-any.whl (413 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.9/413.9 kB 8.0 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
# Successfully installed colorlog-6.10.1 optuna-4.7.0

# %%
import optuna
import lightgbm as lgb
from sklearn.model_selection import cross_val_score
import numpy as np

# Convert to numpy (faster, avoids pandas issues)
X_np = X.values.astype('float32')
y_np = y.values.ravel()
X_test_np = X_test.values.astype('float32')

def objective(trial):
    params = {
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2),
        'num_leaves': trial.suggest_int('num_leaves', 20, 100),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.5, 1.0),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.5, 1.0),
        'bagging_freq': trial.suggest_int('bagging_freq', 1, 10),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 50),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 1.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 1.0),
    }
    model = lgb.LGBMClassifier(**params, n_estimators=500, random_state=42, n_jobs=-1, verbose=-1)
    score = np.mean(cross_val_score(model, X_np, y_np, cv=3, scoring='roc_auc'))
    return score

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=30)   # 30 trials * 3 folds = 90 fits, ~30-40 min

print("Best params:", study.best_params)
print("Best CV:", study.best_value)
# Out:
# [I 2026-02-27 21:43:05,111] A new study created in memory with name: no-name-1b15779d-ef9d-4a41-9460-c58bfb0a88aa
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [I 2026-02-27 21:44:43,267] Trial 0 finished with value: 0.9545637184872188 and parameters: {'learning_rate': 0.15461066072911364, 'num_leaves': 23, 'max_depth': 7, 'feature_fraction': 0.8865152440160899, 'bagging_fraction': 0.8176253734220291, 'bagging_freq': 9, 'min_child_samples': 44, 'reg_alpha': 0.17468659603176395, 'reg_lambda': 0.7277949176126105}. Best is trial 0 with value: 0.9545637184872188.
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [I 2026-02-27 21:48:01,724] Trial 1 finished with value: 0.9548774251289011 and parameters: {'learning_rate': 0.04224612855129348, 'num_leaves': 86, 'max_depth': 8, 'feature_fraction': 0.8612982182868065, 'bagging_fraction': 0.7883953356568714, 'bagging_freq': 4, 'min_child_samples': 33, 'reg_alpha': 0.4615271527318836, 'reg_lambda': 0.20471246512612395}. Best is trial 1 with value: 0.9548774251289011.
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [I 2026-02-27 21:50:55,095] Trial 2 finished with value: 0.9544064086618524 and parameters: {'learning_rate': 0.012158794914825157, 'num_leaves': 63, 'max_depth': 10, 'feature_fraction': 0.6461802463359789, 'bagging_fraction': 0.5090110416354066, 'bagging_freq': 9, 'min_child_samples': 7, 'reg_alpha': 0.25551674505387645, 'reg_lambda': 0.027806361042682748}. Best is trial 1 with value: 0.9548774251289011.
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [I 2026-02-27 21:53:50,002] Trial 3 finished with value: 0.9528932618888096 and parameters: {'learning_rate': 0.13096727291275087, 'num_leaves': 97, 'max_depth': 9, 'feature_fraction': 0.7768861860634684, 'bagging_fraction': 0.6813881091829455, 'bagging_freq': 2, 'min_child_samples': 20, 'reg_alpha': 0.48813847788276776, 'reg_lambda': 0.5193786164485895}. Best is trial 1 with value: 0.9548774251289011.
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [I 2026-02-27 21:56:58,387] Trial 4 finished with value: 0.9550734013836846 and parameters: {'learning_rate': 0.034126504204156596, 'num_leaves': 83, 'max_depth': 10, 'feature_fraction': 0.5052169968688424, 'bagging_fraction': 0.6046986362095679, 'bagging_freq': 3, 'min_child_samples': 13, 'reg_alpha': 0.15920328370762815, 'reg_lambda': 0.4925865752993216}. Best is trial 4 with value: 0.9550734013836846.
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [I 2026-02-27 21:58:35,889] Trial 5 finished with value: 0.9551900427496961 and parameters: {'learning_rate': 0.07404337810368206, 'num_leaves': 52, 'max_depth': 3, 'feature_fraction': 0.591435607313119, 'bagging_fraction': 0.7232611347426914, 'bagging_freq': 5, 'min_child_samples': 30, 'reg_alpha': 0.47048507073081147, 'reg_lambda': 0.36148259223183565}. Best is trial 5 with value: 0.9551900427496961.
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [I 2026-02-27 22:00:48,928] Trial 6 finished with value: 0.9540061092856892 and parameters: {'learning_rate': 0.14252022192537703, 'num_leaves': 44, 'max_depth': 7, 'feature_fraction': 0.9962841470080479, 'bagging_fraction': 0.7220384624405733, 'bagging_freq': 7, 'min_child_samples': 40, 'reg_alpha': 0.4741292591437899, 'reg_lambda': 0.9729725474145609}. Best is trial 5 with value: 0.9551900427496961.
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [I 2026-02-27 22:03:06,214] Trial 7 finished with value: 0.9548621233298684 and parameters: {'learning_rate': 0.06764657603397634, 'num_leaves': 46, 'max_depth': 12, 'feature_fraction': 0.9438324799708832, 'bagging_fraction': 0.9803069928451407, 'bagging_freq': 6, 'min_child_samples': 27, 'reg_alpha': 0.16742302180675583, 'reg_lambda': 0.2924568435919912}. Best is trial 5 with value: 0.9551900427496961.
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [I 2026-02-27 22:06:23,661] Trial 8 finished with value: 0.9541740942667062 and parameters: {'learning_rate': 0.01109445712060627, 'num_leaves': 74, 'max_depth': 11, 'feature_fraction': 0.9938401655699489, 'bagging_fraction': 0.5048879951866758, 'bagging_freq': 2, 'min_child_samples': 24, 'reg_alpha': 0.3467386501784915, 'reg_lambda': 0.6732740504788796}. Best is trial 5 with value: 0.9551900427496961.
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [I 2026-02-27 22:08:41,899] Trial 9 finished with value: 0.9547877594844348 and parameters: {'learning_rate': 0.08535023496042957, 'num_leaves': 46, 'max_depth': 8, 'feature_fraction': 0.7697185224613449, 'bagging_fraction': 0.9628348654146623, 'bagging_freq': 10, 'min_child_samples': 14, 'reg_alpha': 0.07925970542113658, 'reg_lambda': 0.22947460574448675}. Best is trial 5 with value: 0.9551900427496961.
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [I 2026-02-27 22:10:42,920] Trial 10 finished with value: 0.9553195312725343 and parameters: {'learning_rate': 0.10953698118479258, 'num_leaves': 23, 'max_depth': 3, 'feature_fraction': 0.5852683079769899, 'bagging_fraction': 0.8986408533324829, 'bagging_freq': 5, 'min_child_samples': 49, 'reg_alpha': 0.8111361057575353, 'reg_lambda': 0.394960875195504}. Best is trial 10 with value: 0.9553195312725343.
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [I 2026-02-27 22:12:42,355] Trial 11 finished with value: 0.9553242072927578 and parameters: {'learning_rate': 0.10711586240454236, 'num_leaves': 21, 'max_depth': 3, 'feature_fraction': 0.5840108672321671, 'bagging_fraction': 0.8778473606280309, 'bagging_freq': 5, 'min_child_samples': 49, 'reg_alpha': 0.8458985469312007, 'reg_lambda': 0.42532073598237097}. Best is trial 11 with value: 0.9553242072927578.
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [I 2026-02-27 22:14:24,002] Trial 12 finished with value: 0.9552761815633158 and parameters: {'learning_rate': 0.19711313767729055, 'num_leaves': 20, 'max_depth': 3, 'feature_fraction': 0.6380546022221766, 'bagging_fraction': 0.883689761538825, 'bagging_freq': 7, 'min_child_samples': 49, 'reg_alpha': 0.8250954042319901, 'reg_lambda': 0.47201664485995787}. Best is trial 11 with value: 0.9553242072927578.
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [I 2026-02-27 22:16:57,870] Trial 13 finished with value: 0.9551328302813196 and parameters: {'learning_rate': 0.10900546687370782, 'num_leaves': 30, 'max_depth': 5, 'feature_fraction': 0.5193252507581914, 'bagging_fraction': 0.8804650543879806, 'bagging_freq': 5, 'min_child_samples': 50, 'reg_alpha': 0.8631907366842723, 'reg_lambda': 0.665355293315111}. Best is trial 11 with value: 0.9553242072927578.
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [I 2026-02-27 22:18:29,220] Trial 14 finished with value: 0.9552621552676617 and parameters: {'learning_rate': 0.11033951821435899, 'num_leaves': 35, 'max_depth': 4, 'feature_fraction': 0.6807055454018945, 'bagging_fraction': 0.890137395686368, 'bagging_freq': 1, 'min_child_samples': 38, 'reg_alpha': 0.9971799324561015, 'reg_lambda': 0.12726976531323947}. Best is trial 11 with value: 0.9553242072927578.
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [I 2026-02-27 22:20:55,858] Trial 15 finished with value: 0.9547341300750811 and parameters: {'learning_rate': 0.16274560905118216, 'num_leaves': 33, 'max_depth': 5, 'feature_fraction': 0.572232263522515, 'bagging_fraction': 0.831463628687779, 'bagging_freq': 4, 'min_child_samples': 44, 'reg_alpha': 0.6951038491956838, 'reg_lambda': 0.37892247837720255}. Best is trial 11 with value: 0.9553242072927578.
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [I 2026-02-27 22:23:06,329] Trial 16 finished with value: 0.9550925411042929 and parameters: {'learning_rate': 0.09782726868449516, 'num_leaves': 59, 'max_depth': 5, 'feature_fraction': 0.6923794759411058, 'bagging_fraction': 0.9167868926882321, 'bagging_freq': 7, 'min_child_samples': 35, 'reg_alpha': 0.6667658595153698, 'reg_lambda': 0.7999848659432973}. Best is trial 11 with value: 0.9553242072927578.
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [I 2026-02-27 22:25:33,402] Trial 17 finished with value: 0.9549260000772293 and parameters: {'learning_rate': 0.12547202715652017, 'num_leaves': 30, 'max_depth': 6, 'feature_fraction': 0.5787985456971183, 'bagging_fraction': 0.994416973460937, 'bagging_freq': 6, 'min_child_samples': 44, 'reg_alpha': 0.6537848521071653, 'reg_lambda': 0.40307024222721366}. Best is trial 11 with value: 0.9553242072927578.
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [I 2026-02-27 22:27:15,579] Trial 18 finished with value: 0.9553070892390663 and parameters: {'learning_rate': 0.17341807074790744, 'num_leaves': 20, 'max_depth': 3, 'feature_fraction': 0.724837858990214, 'bagging_fraction': 0.9333235463046722, 'bagging_freq': 4, 'min_child_samples': 50, 'reg_alpha': 0.993312336240358, 'reg_lambda': 0.5840860183435906}. Best is trial 11 with value: 0.9553242072927578.
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [I 2026-02-27 22:29:33,203] Trial 19 finished with value: 0.9552652295097676 and parameters: {'learning_rate': 0.06502409084940192, 'num_leaves': 38, 'max_depth': 4, 'feature_fraction': 0.5493980928326322, 'bagging_fraction': 0.8402807295619631, 'bagging_freq': 8, 'min_child_samples': 40, 'reg_alpha': 0.7932083581529108, 'reg_lambda': 0.857507252948647}. Best is trial 11 with value: 0.9553242072927578.
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [I 2026-02-27 22:31:34,084] Trial 20 finished with value: 0.9552451877251822 and parameters: {'learning_rate': 0.12008235642045617, 'num_leaves': 64, 'max_depth': 4, 'feature_fraction': 0.629635057813615, 'bagging_fraction': 0.78514833259579, 'bagging_freq': 5, 'min_child_samples': 46, 'reg_alpha': 0.9044886447904432, 'reg_lambda': 0.5878242143434299}. Best is trial 11 with value: 0.9553242072927578.
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [I 2026-02-27 22:33:12,908] Trial 21 finished with value: 0.9553104968068382 and parameters: {'learning_rate': 0.1876393009471645, 'num_leaves': 23, 'max_depth': 3, 'feature_fraction': 0.7351749402876983, 'bagging_fraction': 0.9401203859119333, 'bagging_freq': 4, 'min_child_samples': 50, 'reg_alpha': 0.9787975609902343, 'reg_lambda': 0.5686344004818922}. Best is trial 11 with value: 0.9553242072927578.
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [I 2026-02-27 22:34:55,936] Trial 22 finished with value: 0.9552779453818259 and parameters: {'learning_rate': 0.19597532361148856, 'num_leaves': 25, 'max_depth': 3, 'feature_fraction': 0.7318647261739455, 'bagging_fraction': 0.9293460504449265, 'bagging_freq': 3, 'min_child_samples': 45, 'reg_alpha': 0.7518056004644803, 'reg_lambda': 0.4295944595232195}. Best is trial 11 with value: 0.9553242072927578.
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [I 2026-02-27 22:36:57,042] Trial 23 finished with value: 0.9552635191978253 and parameters: {'learning_rate': 0.0909592783478565, 'num_leaves': 40, 'max_depth': 4, 'feature_fraction': 0.8192430931847262, 'bagging_fraction': 0.8626196483894117, 'bagging_freq': 3, 'min_child_samples': 38, 'reg_alpha': 0.9286096725470478, 'reg_lambda': 0.2796717548662575}. Best is trial 11 with value: 0.9553242072927578.
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [I 2026-02-27 22:39:00,661] Trial 24 finished with value: 0.9546873027174668 and parameters: {'learning_rate': 0.17202631121650283, 'num_leaves': 26, 'max_depth': 6, 'feature_fraction': 0.6104228888922267, 'bagging_fraction': 0.9576574972156602, 'bagging_freq': 6, 'min_child_samples': 47, 'reg_alpha': 0.7745166188399006, 'reg_lambda': 0.5596984968300047}. Best is trial 11 with value: 0.9553242072927578.
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [I 2026-02-27 22:40:41,880] Trial 25 finished with value: 0.9553334725597663 and parameters: {'learning_rate': 0.14178801801933952, 'num_leaves': 28, 'max_depth': 3, 'feature_fraction': 0.6775517777773777, 'bagging_fraction': 0.9179109086797103, 'bagging_freq': 4, 'min_child_samples': 41, 'reg_alpha': 0.5704863720785183, 'reg_lambda': 0.3452364749193629}. Best is trial 25 with value: 0.9553334725597663.
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [I 2026-02-27 22:42:52,369] Trial 26 finished with value: 0.9546567219814879 and parameters: {'learning_rate': 0.1387057131926947, 'num_leaves': 30, 'max_depth': 6, 'feature_fraction': 0.675402406282488, 'bagging_fraction': 0.7965998648830678, 'bagging_freq': 5, 'min_child_samples': 41, 'reg_alpha': 0.5607252758770032, 'reg_lambda': 0.3224186762615841}. Best is trial 25 with value: 0.9553334725597663.
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [I 2026-02-27 22:45:21,828] Trial 27 finished with value: 0.9548093083554953 and parameters: {'learning_rate': 0.14511487877664986, 'num_leaves': 52, 'max_depth': 5, 'feature_fraction': 0.5458649120888175, 'bagging_fraction': 0.7589658751383275, 'bagging_freq': 2, 'min_child_samples': 35, 'reg_alpha': 0.570520794880855, 'reg_lambda': 0.1433888606812182}. Best is trial 25 with value: 0.9553334725597663.
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [I 2026-02-27 22:47:16,264] Trial 28 finished with value: 0.9552015353252079 and parameters: {'learning_rate': 0.11704934649224183, 'num_leaves': 39, 'max_depth': 4, 'feature_fraction': 0.6586626796713251, 'bagging_fraction': 0.902290159848026, 'bagging_freq': 6, 'min_child_samples': 42, 'reg_alpha': 0.37652740039115895, 'reg_lambda': 0.21831323837534633}. Best is trial 25 with value: 0.9553334725597663.
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [I 2026-02-27 22:48:47,179] Trial 29 finished with value: 0.9553282506351973 and parameters: {'learning_rate': 0.1492681992654047, 'num_leaves': 26, 'max_depth': 3, 'feature_fraction': 0.702187224211212, 'bagging_fraction': 0.8475863500474607, 'bagging_freq': 8, 'min_child_samples': 46, 'reg_alpha': 0.6132841209190188, 'reg_lambda': 0.43791259176116387}. Best is trial 25 with value: 0.9553334725597663.
# Best params: {'learning_rate': 0.14178801801933952, 'num_leaves': 28, 'max_depth': 3, 'feature_fraction': 0.6775517777773777, 'bagging_fraction': 0.9179109086797103, 'bagging_freq': 4, 'min_child_samples': 41, 'reg_alpha': 0.5704863720785183, 'reg_lambda': 0.3452364749193629}
# Best CV: 0.9553334725597663

# %%
import xgboost as xgb

# Train final LightGBM with best params
best_lgb_params = study.best_params.copy()
best_lgb_params['n_estimators'] = 1000   # can be increased if early stopping used, but here we fix

lgb_final = lgb.LGBMClassifier(**best_lgb_params, random_state=42, n_jobs=-1, verbose=-1)
lgb_final.fit(X_np, y_np)

lgb_pred = lgb_final.predict_proba(X_test_np)[:, 1]

# If you want to blend with your best XGBoost (the one that gave 0.95356), load it or retrain quickly
# Example: retrain XGBoost with best params (use the same best_xgb_params from earlier)
best_xgb_params = {
    'learning_rate': 0.150165,
    'max_depth': 4,
    'subsample': 0.9845,
    'colsample_bytree': 0.5068,
    'min_child_weight': 7,
    'gamma': 0.3314,
    'reg_alpha': 0.9975,
    'reg_lambda': 2.5372
}

xgb_model = xgb.XGBClassifier(**best_xgb_params, n_estimators=1000, random_state=42, n_jobs=-1)
xgb_model.fit(X_np, y_np)
xgb_pred = xgb_model.predict_proba(X_test_np)[:, 1]

# Blend (simple average)
blend_pred = (xgb_pred + lgb_pred) / 2

# Submission
submission = pd.DataFrame({'id': test_ids, 'Heart Disease': blend_pred})
submission.to_csv('final_blend.csv', index=False)

from google.colab import files
files.download('final_blend.csv')
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(

# %%
import numpy as np
import pandas as pd
import xgboost as xgb

# --- Make sure X_np, y_np, X_test_np, test_ids are defined ---
# (If not, rerun the data prep cell that creates X, X_test, etc., and converts to numpy)

# Your best XGBoost params from Optuna
best_xgb_params = {
    'learning_rate': 0.150165,
    'max_depth': 4,
    'subsample': 0.9845,
    'colsample_bytree': 0.5068,
    'min_child_weight': 7,
    'gamma': 0.3314,
    'reg_alpha': 0.9975,
    'reg_lambda': 2.5372
}

# Three different seeds
seeds = [42, 123, 456]
predictions = []

for i, seed in enumerate(seeds):
    print(f"Training XGBoost {i+1} with seed {seed}...")
    model = xgb.XGBClassifier(
        **best_xgb_params,
        n_estimators=1000,
        random_state=seed,
        n_jobs=-1,
        eval_metric='auc'
    )
    model.fit(X_np, y_np)
    pred = model.predict_proba(X_test_np)[:, 1]
    predictions.append(pred)

# Average
avg_pred = np.mean(predictions, axis=0)

# Submission
submission = pd.DataFrame({'id': test_ids, 'Heart Disease': avg_pred})
submission.to_csv('xgb_ensemble_3.csv', index=False)

from google.colab import files
files.download('xgb_ensemble_3.csv')
# Out:
# Training XGBoost 1 with seed 42...
# Training XGBoost 2 with seed 123...
# Training XGBoost 3 with seed 456...
